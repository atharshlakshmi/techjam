# %%
import os
import pandas as pd
from huggingface_hub import InferenceClient

data_path = "../data/clean_data.csv"
df = pd.read_csv(data_path)

df2 = df.head(10).copy()

json_str = df2.to_json(orient='records')

print(json_str)

client = InferenceClient(
    provider="nscale",
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="Qwen/Qwen3-4B-Instruct-2507",
    messages=[
        {
            "role": "user",
            "content": 
            f'''
            
            I will give you a list of reviews of restaurants and you need to label the reviews as one of the categories below
            1. Advertisement
            2. Irrelevant
            3. Rant
            4. Normal
            Edit this JSON file and add one column for labels as "labels": {json_str}
            Only return the JSON.
            
            '''
        }
    ],
)

print(completion.choices[0].message["content"])
# Out:
# [{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Gulsum Akar","text":"We went to Marmaris with my wife for a holiday. We chose this restaurant as a place for dinner based on the reviews and because we wanted juicy food. When we first went there was a serious queue. You proceed by taking the food you want in the form of an open buffet. Both vegetable dishes and meat dishes were plentiful. There was also dessert for those who wanted it. After you get what you want you pay at the cashier. They don't go through cards they work in cash. There was a lot of food variety. And the food prices were unbelievably cheap. We paid only 84 TL for all the meals here. It included buttermilk and bread. But unfortunately I can't say it's too clean as a place..","rating":5,"rating_category":"taste"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Oguzhan Cetin","text":"During my holiday in Marmaris we ate here to fit the food. It's really good that the food is cheap and nice. Eating as much bread as you want is a big plus for those who are not satisfied without bread. It is a place that I can recommend to those who will go to Marmaris. On July 1 there was a small increase but even the price hike is cheap. I leave the photo of the latest prices and breakfast below. there was a serious queue. You proceed by taking the food you want in the form of an open buffet. Both vegetable dishes and meat dishes were plentiful. There was also dessert for those who wanted it. After you get what you want you pay at the cashier. They don't go through cards they work in cash. There was a lot of food variety. And the food prices were unbelievably cheap. We paid only 84 TL for all the meals here. It included buttermilk and bread. But unfortunately I can't say it's too clean as a place..","rating":4,"rating_category":"menu"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Yasin Kuyu","text":"Prices are very affordable. The menu in the photo cost 108 liras. You have to wait 10-15 minutes for food. Staff is annoying. Well it tastes good. Boiled meat was delicious.","rating":3,"rating_category":"outdoor_atmosphere"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Orhan Kapu","text":"Turkey's cheapest artisan restaurant and its food is delicious!","rating":5,"rating_category":"indoor_atmosphere"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Ozgur Sati","text":"I don't know what you will look for in terms of price performance point; taste; but yigit restaurant writes a big plus for those who come to work in this region.","rating":3,"rating_category":"menu"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Arda Karaca","text":"Generally good.","rating":4,"rating_category":"indoor_atmosphere"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"\u0130rem Eren","text":"What you see is 125 TL in total. It's a pretty convenient place. We can say that it is an artisan restaurant; you should not expect a restaurant; but they are still quite good in terms of price and performance. As of July 1; prices will increase","rating":5,"rating_category":"taste"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Nadia Salim","text":"Delicious food at rock bottom prices. Friendly staff; Highly recommend","rating":5,"rating_category":"taste"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Mehmet Eser","text":"Every time I go, I still experience the amazement I experienced years ago as if it were the first time. There is no need to explain. Folk hero is a business.","rating":5,"rating_category":"outdoor_atmosphere"},{"business_name":"Haci'nin Yeri - Yigit Lokantasi","author_name":"Celal Ozer","text":"The most f\/p of all businesses I've seen.","rating":5,"rating_category":"indoor_atmosphere"}]
# [
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Gulsum Akar",
#     "text": "We went to Marmaris with my wife for a holiday. We chose this restaurant as a place for dinner based on the reviews and because we wanted juicy food. When we first went there was a serious queue. You proceed by taking the food you want in the form of an open buffet. Both vegetable dishes and meat dishes were plentiful. There was also dessert for those who wanted it. After you get what you want you pay at the cashier. They don't go through cards they work in cash. There was a lot of food variety. And the food prices were unbelievably cheap. We paid only 84 TL for all the meals here. It included buttermilk and bread. But unfortunately I can't say it's too clean as a place..",
#     "rating": 5,
#     "rating_category": "taste",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Oguzhan Cetin",
#     "text": "During my holiday in Marmaris we ate here to fit the food. It's really good that the food is cheap and nice. Eating as much bread as you want is a big plus for those who are not satisfied without bread. It is a place that I can recommend to those who will go to Marmaris. On July 1 there was a small increase but even the price hike is cheap. I leave the photo of the latest prices and breakfast below. there was a serious queue. You proceed by taking the food you want in the form of an open buffet. Both vegetable dishes and meat dishes were plentiful. There was also dessert for those who wanted it. After you get what you want you pay at the cashier. They don't go through cards they work in cash. There was a lot of food variety. And the food prices were unbelievably cheap. We paid only 84 TL for all the meals here. It included buttermilk and bread. But unfortunately I can't say it's too clean as a place..",
#     "rating": 4,
#     "rating_category": "menu",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Yasin Kuyu",
#     "text": "Prices are very affordable. The menu in the photo cost 108 liras. You have to wait 10-15 minutes for food. Staff is annoying. Well it tastes good. Boiled meat was delicious.",
#     "rating": 3,
#     "rating_category": "outdoor_atmosphere",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Orhan Kapu",
#     "text": "Turkey's cheapest artisan restaurant and its food is delicious!",
#     "rating": 5,
#     "rating_category": "indoor_atmosphere",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Ozgur Sati",
#     "text": "I don't know what you will look for in terms of price performance point; taste; but yigit restaurant writes a big plus for those who come to work in this region.",
#     "rating": 3,
#     "rating_category": "menu",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Arda Karaca",
#     "text": "Generally good.",
#     "rating": 4,
#     "rating_category": "indoor_atmosphere",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "İrem Eren",
#     "text": "What you see is 125 TL in total. It's a pretty convenient place. We can say that it is an artisan restaurant; you should not expect a restaurant; but they are still quite good in terms of price and performance. As of July 1; prices will increase",
#     "rating": 5,
#     "rating_category": "taste",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Nadia Salim",
#     "text": "Delicious food at rock bottom prices. Friendly staff; Highly recommend",
#     "rating": 5,
#     "rating_category": "taste",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Mehmet Eser",
#     "text": "Every time I go, I still experience the amazement I experienced years ago as if it were the first time. There is no need to explain. Folk hero is a business.",
#     "rating": 5,
#     "rating_category": "outdoor_atmosphere",
#     "labels": "Normal"
#   },
#   {
#     "business_name": "Haci'nin Yeri - Yigit Lokantasi",
#     "author_name": "Celal Ozer",
#     "text": "The most f\/p of all businesses I've seen.",
#     "rating": 5,
#     "rating_category": "indoor_atmosphere",
#     "labels": "Normal"
#   }
# ]
